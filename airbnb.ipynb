# %% [markdown]
# <a href="https://colab.research.google.com/github/PreethikaDinesh/Airbnb-Analysis/blob/main/airbnb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install pymongo
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 670.1/670.1 kB 10.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 307.7/307.7 kB 33.8 MB/s eta 0:00:00
# ...

# %%
import pymongo
import pandas as pd

# %%
con_obj = pymongo.MongoClient("mongodb://preethi:guvi2024@ac-40kiqlq-shard-00-00.8zhqhxd.mongodb.net:27017,ac-40kiqlq-shard-00-01.8zhqhxd.mongodb.net:27017,ac-40kiqlq-shard-00-02.8zhqhxd.mongodb.net:27017/?ssl=true&replicaSet=atlas-3eyd5j-shard-0&authSource=admin&retryWrites=true&w=majority&appName=Cluster0")

db = con_obj['sample_airbnb']

collection = db['listingsAndReviews']

# %%
req_column = []
for i in collection.find():
    req_data = dict(Id = i['_id'],
               Name = i.get('name'),
                Description = i['description'],
                House_rules = i.get('house_rules'),
                Property_type = i['property_type'],
                Room_type = i['room_type'],
                Bed_type = i['bed_type'],
                Min_nights = int(i['minimum_nights']),
                Max_nights = int(i['maximum_nights']),
                Cancellation_policy = i['cancellation_policy'],
                Accomodates = i['accommodates'],
                Total_bedrooms = i.get('bedrooms'),
                Total_beds = i.get('beds'),
                Price = i['price'],
                Security_deposit = i.get('security_deposit'),
                Cleaning_fee = i.get('cleaning_fee'),
                Extra_people = i['extra_people'],
                Guests_included= i['guests_included'],
                No_of_reviews = i['number_of_reviews'],
                Review_scores = i['review_scores'].get('review_scores_rating'),
                Amenities = ', '.join(i['amenities']),
                Host_id = i['host']['host_id'],
                Host_name = i['host']['host_name'],
                Host_Neighbourhood=i['host']['host_neighbourhood'],
                Host_Total_Listings_Count=i['host']['host_total_listings_count'],
                Street = i['address']['street'],
                Country = i['address']['country'],
                Country_code = i['address']['country_code'],
                Location_type = i['address']['location']['type'],
                Longitude = i['address']['location']['coordinates'][0],
                Latitude = i['address']['location']['coordinates'][1],
                Is_location_exact = i['address']['location']['is_location_exact'],
                Availability_30=i['availability']['availability_30'],
                Availability_60=i['availability']['availability_60'],
                Availability_90=i['availability']['availability_90'],
                Availability_365=i['availability']['availability_365'],
                Rating=i['review_scores']['review_scores_rating'] if 'review_scores_rating' in i['review_scores'] else 0


    )
    req_column.append(req_data)

# %%
df = pd.DataFrame(req_column)
df
# Out:
#             Id                                               Name  \
# 0     10006546                            Ribeira Charming Duplex
# 1     10009999                       Horto flat with small garden
# 2      1001265                   Ocean View Waikiki Marina w/prkg
# 3     10021707                           Private Room in Bushwick
# 4     10030955                        Apt Linda Vista Lagoa - Rio
# ...        ...                                                ...
# 5550   9983221                      Cozy apartment downtown Porto
# 5551   9985696                                    Kadıköy-Altıyol
# 5552   9987200       The best suite in Copacabana (total privacy)
# 5553   9990304     March Madness Special! Aina Nalu Platinum D107
# 5554   9993190  Just Steps from the Ocean at Premier Platinum ...
#
#                                             Description  \
# 0     Fantastic duplex apartment with three bedrooms...
# 1     One bedroom + sofa-bed in quiet and bucolic ne...
# ...

# %%
df['Description'] = df.Description.apply(lambda x : 'not mentioned' if x =='' else x )


df['Name'] = df.Name.apply(lambda x : 'not mentioned' if x =='' else x )


df['Host_Neighbourhood'] = df['Host_Neighbourhood'].replace("",method='ffill')


df.isnull().sum()
# Out:
# Id                              0
# Name                            0
# Description                     0
# House_rules                     0
# Property_type                   0
# Room_type                       0
# Bed_type                        0
# Min_nights                      0
# Max_nights                      0
# Cancellation_policy             0
# Accomodates                     0
# Total_bedrooms                  5
# Total_beds                     13
# Price                           0
# Security_deposit             2084
# Cleaning_fee                 1531
# Extra_people                    0
# Guests_included                 0
# No_of_reviews                   0
# Review_scores                1474
# Amenities                       0
# Host_id                         0
# Host_name                       0
# Host_Neighbourhood              0
# Host_Total_Listings_Count       0
# Street                          0
# Country                         0
# ...

# %%
df['Min_nights'] = df.Min_nights.apply(lambda x : int(x))

df['Max_nights'] = df.Max_nights.apply(lambda x : int(x))

df['No_of_reviews'] = df.No_of_reviews.apply(lambda x : int(x))

df['Price'] = df.Price.astype(str).astype(float)

df.Host_Total_Listings_Count = df.Host_Total_Listings_Count.apply(lambda x : int(x))

df.Longitude	 = df.Longitude.apply(lambda x : float(x))

df.Latitude = df.Latitude.apply(lambda x : float(x))

df.Availability_30 = df.Availability_30.apply(lambda x : int(x))

df.Availability_60 = df.Availability_60.apply(lambda x : int(x))

df.Availability_90 =  df.Availability_90.apply(lambda x : int(x))

df.Availability_365 = df.Availability_365.apply(lambda x : int(x))

df.Rating = df.Rating.apply(lambda x : int(x))

df.loc[df.query('Host_Neighbourhood == "" ').index,'Host_Neighbourhood']  = 'Copacabana'

# %%
df.dropna(axis=1, inplace=True)

# %%
df.isna().sum()
# Out:
# Id                           0
# Name                         0
# Description                  0
# House_rules                  0
# Property_type                0
# Room_type                    0
# Bed_type                     0
# Min_nights                   0
# Max_nights                   0
# Cancellation_policy          0
# Accomodates                  0
# Price                        0
# Extra_people                 0
# Guests_included              0
# No_of_reviews                0
# Amenities                    0
# Host_id                      0
# Host_name                    0
# Host_Neighbourhood           0
# Host_Total_Listings_Count    0
# Street                       0
# Country                      0
# Country_code                 0
# Location_type                0
# Longitude                    0
# Latitude                     0
# Is_location_exact            0
# Availability_30              0
# Availability_60              0
# Availability_90              0
# ...

# %%
df.columns
# Out:
# Index(['Id', 'Name', 'Description', 'House_rules', 'Property_type',
#        'Room_type', 'Bed_type', 'Min_nights', 'Max_nights',
#        'Cancellation_policy', 'Accomodates', 'Price', 'Extra_people',
#        'Guests_included', 'No_of_reviews', 'Amenities', 'Host_id', 'Host_name',
#        'Host_Neighbourhood', 'Host_Total_Listings_Count', 'Street', 'Country',
#        'Country_code', 'Location_type', 'Longitude', 'Latitude',
#        'Is_location_exact', 'Availability_30', 'Availability_60',
#        'Availability_90', 'Availability_365', 'Rating'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Id                            object
# Name                          object
# Description                   object
# House_rules                   object
# Property_type                 object
# Room_type                     object
# Bed_type                      object
# Min_nights                     int64
# Max_nights                     int64
# Cancellation_policy           object
# Accomodates                    int64
# Price                        float64
# Extra_people                  object
# Guests_included               object
# No_of_reviews                  int64
# Amenities                     object
# Host_id                       object
# Host_name                     object
# Host_Neighbourhood            object
# Host_Total_Listings_Count      int64
# Street                        object
# Country                       object
# Country_code                  object
# Location_type                 object
# Longitude                    float64
# ...

# %%
df
# Out:
#             Id                                               Name  \
# 0     10006546                            Ribeira Charming Duplex
# 1     10009999                       Horto flat with small garden
# 2      1001265                   Ocean View Waikiki Marina w/prkg
# 3     10021707                           Private Room in Bushwick
# 4     10030955                        Apt Linda Vista Lagoa - Rio
# ...        ...                                                ...
# 5550   9983221                      Cozy apartment downtown Porto
# 5551   9985696                                    Kadıköy-Altıyol
# 5552   9987200       The best suite in Copacabana (total privacy)
# 5553   9990304     March Madness Special! Aina Nalu Platinum D107
# 5554   9993190  Just Steps from the Ocean at Premier Platinum ...
#
#                                             Description  \
# 0     Fantastic duplex apartment with three bedrooms...
# 1     One bedroom + sofa-bed in quiet and bucolic ne...
# ...

# %%
df.to_csv('Airbnb_dataset.csv',index=False)

# %%
import pandas as pd

# Read the CSV file into a DataFrame
df = pd.read_csv("/content/Airbnb_dataset.csv")

# Display the 'Amenities' column
if 'Cancellation_policy' in df.columns:
    amenities_column = df['Cancellation_policy']
    print("Amenities Column:")
    print(amenities_column)
else:
    print("Amenities column not found in the dataset.")
# Out:
# Amenities Column:
# 0                          moderate
# 1                          flexible
# 2       strict_14_with_grace_period
# 3                          flexible
# 4                          flexible
#                    ...
# 5550    strict_14_with_grace_period
# 5551                       flexible
# 5552                       flexible
# 5553    strict_14_with_grace_period
# 5554    strict_14_with_grace_period
# Name: Cancellation_policy, Length: 5555, dtype: object
